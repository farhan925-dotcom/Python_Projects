# %% [markdown]
# <a href="https://colab.research.google.com/github/farhan925-dotcom/Python_Projects/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q-No 1   Multiplication Table

# Get input from the user
n = int(input("Enter a number to display its multiplication table: "))

# Generate and display the table from 1 to 10
print(f"\nMultiplication Table of {n}:")
for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")

    # Ask the user for the number of terms
n = int(input("Enter the number of terms: "))

# Q-2    Initialize the first two Fibonacci numbers
a, b = 0, 1

print("Fibonacci Series:")

# Generate and display the Fibonacci series
for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c


    # Q-N03  Fibonacci Series Generator

# Ask the user for the number of terms
n = int(input("Enter the number of terms: "))

# Initialize the first two Fibonacci numbers
a, b = 0, 1

print("Fibonacci Series:")

# Generate and display the Fibonacci series
for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c

# Q-No 4   Prime Number Checker

# Get input from the user
n = int(input("Enter a number: "))

# Prime numbers are greater than 1
if n > 1:
    # Check for factors
    for i in range(2, n):
        if n % i == 0:
            print(n, "is not a prime number.")
            break
    else:
        print(n, "is a prime number.")
else:
    print(n, "is not a prime number (prime numbers are greater than 1).")



# Q-No 5  Power Calculation

# Get input from the user
base = float(input("Enter the base number (b): "))
exponent = float(input("Enter the exponent (e): "))

# Calculate power
result = base ** exponent

# Display the result
print(f"{base} raised to the power {exponent} is: {result}")



# Q-No 6 Reverse Number Program

# Get input from the user
n = int(input("Enter an integer: "))

# Initialize variable to store reversed number
reverse = 0
original = n  # keep a copy for display

# Reverse the number using a loop
while n > 0:
    digit = n % 10          # Get the last digit
    reverse = reverse * 10 + digit  # Add digit to reversed number
    n //= 10                # Remove the last digit from n

# Display the result
print("The reverse of", original, "is:", reverse)



# Q-N0 7  Guess Until Correct

# Set the secret number
secret_number = 7  # you can change this value

while True:
    # Ask the user for their guess
    guess = int(input("Guess the secret number: "))

    # Check if the guess is correct
    if guess == secret_number:
        print("🎉 Correct! You guessed the secret number!")
        break
    else:
        print("❌ Wrong guess, try again!")
# Out:
# Enter a number to display its multiplication table: 4
#
# Multiplication Table of 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# Enter the number of terms: 7
# Fibonacci Series:
# 0 1 1 2 3 5 8 Enter the number of terms: 0
# Fibonacci Series:
# Enter a number: 66
# 66 is not a prime number.
# Enter the base number (b): 7
# Enter the exponent (e): 9
# 7.0 raised to the power 9.0 is: 40353607.0
# Enter an integer: 4
# The reverse of 4 is: 4
# Guess the secret number: 6
# ❌ Wrong guess, try again!
# Guess the secret number: 99
# ❌ Wrong guess, try again!
# Guess the secret number: 77
# ❌ Wrong guess, try again!
# Guess the secret number: 44
# ❌ Wrong guess, try again!
# Guess the secret number: 666
# ❌ Wrong guess, try again!
# Guess the secret number: 22
# ❌ Wrong guess, try again!
# Guess the secret number: 1
# ❌ Wrong guess, try again!
