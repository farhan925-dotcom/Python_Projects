# %% [markdown]
# <a href="https://colab.research.google.com/github/farhan925-dotcom/Python_Projects/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment No2 Question No1: Comparing Rectangle Areas

# Get input for the first rectangle
length1 = float(input("Enter the length of the first rectangle: "))
width1 = float(input("Enter the width of the first rectangle: "))

# Calculate area of the first rectangle
area1 = length1 * width1

# Get input for the second rectangle
length2 = float(input("Enter the length of the second rectangle: "))
width2 = float(input("Enter the width of the second rectangle: "))

# Calculate area of the second rectangle
area2 = length2 * width2

# Compare the two areas
print("\nArea of first rectangle:", area1)
print("Area of second rectangle:", area2)

if area1 > area2:
    print("The first rectangle has a larger area.")
elif area2 > area1:
    print("The second rectangle has a larger area.")
else:
    print("Both rectangles have the same area.")



    # Q2: Determine if a number is Even/Odd and Positive/Negative

# Get input from the user
num = int(input("Enter a number: "))

# Check if the number is positive, negative, or zero
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# Check if the number is even or odd
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")


# Q3: Tax Calculation by Income Slab

# Get salary input from the user
salary = float(input("Enter your salary: "))

# Determine tax rate based on salary slab
if salary > 100000:
    tax_rate = 0.20
elif salary > 50000:
    tax_rate = 0.10
else:
    tax_rate = 0.05

# Q-No4 Calculate tax and salary after tax
tax_amount = salary * tax_rate
salary_after_tax = salary - tax_amount

# Display results
print("\n--- Tax Calculation ---")
print("Salary before tax:", salary)
print("Applicable tax rate:", tax_rate * 100, "%")
print("Tax amount:", tax_amount)
print("Salary after tax:", salary_after_tax)


# Q4: Shipping Cost Calculation

# Get parcel weight from the user
weight = float(input("Enter the weight of the parcel (in kg): "))

# Determine rate per kg based on weight
if weight > 20:
    rate = 15
elif weight >= 10:
    rate = 10
else:
    rate = 5

# Q-No5 Calculate total shipping cost
shipping_cost = weight * rate

# Display the result
print("\n--- Shipping Cost Details ---")
print("Parcel Weight:", weight, "kg")
print("Rate per kg: Rs.", rate)
print("Total Shipping Cost: Rs.", shipping_cost)


# Q5: Smallest and Greatest of Three Numbers

# Get input from the user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

# Find smallest and greatest numbers
smallest = min(num1, num2, num3)
greatest = max(num1, num2, num3)

# Display the results
print("\n--- Results ---")
print("Smallest number:", smallest)
print("Greatest number:", greatest)
# Out:
# Enter the length of the first rectangle: 121212
# Enter the width of the first rectangle: 111111
# Enter the length of the second rectangle: 22222
# Enter the width of the second rectangle: 22
#
# Area of first rectangle: 13467986532.0
# Area of second rectangle: 488884.0
# The first rectangle has a larger area.
# Enter a number: 11
# The number is positive.
# The number is odd.
# Enter your salary: 22222
#
# --- Tax Calculation ---
# Salary before tax: 22222.0
# Applicable tax rate: 5.0 %
# Tax amount: 1111.1000000000001
# Salary after tax: 21110.9
# Enter the weight of the parcel (in kg): 2
#
# --- Shipping Cost Details ---
# Parcel Weight: 2.0 kg
# Rate per kg: Rs. 5
# Total Shipping Cost: Rs. 10.0
# Enter first number: 23
# Enter second number: 33
# Enter third number: 44
#
# --- Results ---
# Smallest number: 23.0
# Greatest number: 44.0
